# %% [markdown]
# <a href="https://colab.research.google.com/github/gajesh2/IHD-USING-ML-SHAP/blob/main/finalproject2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# --- Placeholder code to create results_df ---
# Replace this with your actual code to create the results_df DataFrame
# For example, if you have a previous step that generates this DataFrame,
# ensure that cell is executed before the Snowflake upload cell.

# Example: Creating a simple dummy DataFrame
data = {'prediction_column': [0.85, 0.12, 0.93],
        'shap_value_1': [0.1, -0.05, 0.2],
        'shap_value_2': [-0.02, 0.15, -0.08]}
results_df = pd.DataFrame(data)

print("Created 'results_df':")
display(results_df.head())
print(f"Number of rows in results_df: {len(results_df)}")
# --- End of placeholder code ---
# Out:
# Created 'results_df':
#    prediction_column  shap_value_1  shap_value_2
# 0               0.85          0.10         -0.02
# 1               0.12         -0.05          0.15
# 2               0.93          0.20         -0.08
# Number of rows in results_df: 3

# %%
# Install the required snowflake connector library
# !pip install snowflake-connector-python
# !pip install pandas

# The rest of your code remains the same

# %%
# Import the necessary modules
import snowflake.connector
from snowflake.connector.pandas_tools import write_pandas
import pandas as pd # Ensure pandas is imported if not already

# Install the required snowflake connector library
# !pip install snowflake-connector-python
# !pip install pandas

# Define the table name
SNOWFLAKE_RESULTS_TABLE ="IHD_PREDICTIONS_AND_SHAP_RESULTS"

# --- Placeholder code to create results_df (Make sure this block is executed) ---
# Example: Creating a simple dummy DataFrame
data = {'prediction_column': [0.85, 0.12, 0.93],
        'shap_value_1': [0.1, -0.05, 0.2],
        'shap_value_2': [-0.02, 0.15, -0.08]}
results_df = pd.DataFrame(data)

print("Created 'results_df':")
from IPython.display import display # Import display if not already
display(results_df.head())
print(f"Number of rows in results_df: {len(results_df)}")
# --- End of placeholder code ---


print(f"\nAttempting to connect for uploading results to {SNOWFLAKE_RESULTS_TABLE}...") # Added space for clarity

# Establish Snowflake connection
conn_results = snowflake.connector.connect(
    user="Gajesh",
    password="Gajeshwaran@2580",
    account="ylvndnf-ub40781",
    warehouse="COMPUTE_WH",
    database="HEART_DB",
    schema="IHD_SCHEMA",
)

print("Snowflake connection established for results upload.")

cursor_results = conn_results.cursor()
# Ensure standard spaces in SQL commands
cursor_results.execute("USE DATABASE HEART_DB;")
cursor_results.execute("USE SCHEMA HEART_DB.IHD_SCHEMA;")

# Upload to Snowflake
success_results, nchunks_results, nrows_results, _ = write_pandas(
    conn_results,
    results_df,
    table_name=SNOWFLAKE_RESULTS_TABLE,
    database="HEART_DB",
    schema="IHD_SCHEMA",
    quote_identifiers=False,
)

print(f" Results uploaded: success={success_results}, chunks={nchunks_results}, rows={nrows_results}")

# Close cursor and connection
cursor_results.close()
conn_results.close()
print("Snowflake connection closed.")
# Out:
# ...
# Created 'results_df':
#    prediction_column  shap_value_1  shap_value_2
# 0               0.85          0.10         -0.02
# 1               0.12         -0.05          0.15
# 2               0.93          0.20         -0.08
# Number of rows in results_df: 3
#
# Attempting to connect for uploading results to IHD_PREDICTIONS_AND_SHAP_RESULTS...
# Snowflake connection established for results upload.
#  Results uploaded: success=True, chunks=1, rows=3
# Snowflake connection closed.
